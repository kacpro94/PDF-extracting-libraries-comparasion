# %%
# Ground Truth dla: oldmansea-20.pdf (Simple Text)
# Kategoria: Fiction / Narrative
# Cel: Sprawdzenie, czy biblioteka zachowuje ciągłość akapitów i poprawne kodowanie cudzysłowów.
# Usunięto nagłówki "Asiaing.com" oraz stopkę z numerem strony "-19-".

ground_truth_simple_1 = """[51] But you haven't got the boy, he thought. You have only yourself and you had better work back to the last line now, in the dark or not in the dark, and cut it away and hook up the two reserve coils. So he did it. It was difficult in the dark and once the fish made a surge that pulled him down on his face and made a cut below his eye. The blood ran down his cheek a little way. But it coagulated and dried before it reached his chin and he worked his way back to the bow and rested against the wood. He adjusted the sack and carefully worked the line so that it came across a new part of his shoulders and, holding it anchored with his shoulders, he carefully felt the pull of the fish and then felt with his hand the progress of the skiff through the water. I wonder what he made that lurch for, he thought. The wire must have slipped on the great hill of his back. Certainly his back cannot feel as badly as mine does. But he cannot pull this skiff forever, no matter how great he is. Now everything is cleared away that might make trouble and I have a big reserve of line; all that a man can ask. "Fish," he said softly, aloud, "I'll stay with you until I am dead."

[52] He'll stay with me too, I suppose, the old man thought and he waited for it to be light. It was cold now in the time before daylight and he pushed against the wood to be warm. I can do it as long as he can, he thought. And in the first light the line extended out and down into the water. The boat moved steadily and when the first edge of the sun rose it was on the old man's right shoulder. "He's headed north," the old man said. The current will have set us far to the eastward, he thought. I wish he would turn with the current. That would show that he was tiring. When the sun had risen further the old man realized that the fish was not tiring. There was only one favorable sign. The slant of the line showed he was swimming at a lesser depth. That did not necessarily mean that he would jump. But he might. "God let him jump," the old man said. "I have enough line to handle him." Maybe if I can increase the tension just a little it will hurt him and he will jump, he thought. Now that it is daylight let him jump so that he'll fill the sacks along his backbone with air and then he cannot go deep to die.

[53] He tried to increase the tension, but the line had been taut up to the very edge of the breaking point since he had hooked the fish and he felt the harshness as he leaned back to pull and knew he could put no more strain on it. I must not jerk it ever, he thought. Each jerk widens the cut the hook makes and then when he does jump he might throw it. Anyway I feel better with the sun and for once I do not have to look into it. There was yellow weed on the line but the old man knew that only made an added drag and he was pleased. It was the yellow Gulf weed that had made so much phosphorescence in the night. "Fish," he said, "I love you and respect you very much. But I will kill you dead before this day ends."
"""

# Ground Truth dla: Ralph_Kimball_Margy_Ross-The_Data_Warehouse_Toolkit-EN-121.pdf
# Kategoria: Technical Text
# Wyzwania: Łamanie linii w środku słów (hyphenation), nagłówki stron.
# Uwaga: Usunąłem nagłówek "Procurement 95" i skleiłem słowa (np. "independent").

ground_truth_simple_2 = """Slowly Changing Dimensions
Up to this point we have pretended that each dimension is logically independent from all the other dimensions. In particular, dimensions have been assumed to be independent of time. Unfortunately, this is not the case in the real world. While dimension table attributes are relatively static, they are not fixed forever. Dimension attributes change, albeit rather slowly, over time.
Dimensional designers must engage business representatives proactively to help determine the appropriate change-handling strategy. We can't simply jump to the conclusion that the business doesn't care about dimension changes just because its representatives didn't mention it during the requirements process. While we're assuming that accurate change tracking is unnecessary, business users may be assuming that the data warehouse will allow them to see the impact of each and every dimension change. Even though we may not want to hear that change tracking is a must-have because we are not looking for any additional development work, it is obviously better to receive the message sooner rather than later.
When we need to track change, it is unacceptable to put everything into the fact table or make every dimension time-dependent to deal with these changes. We would quickly talk ourselves back into a full-blown normalized structure with the consequential loss of understandability and query performance. Instead, we take advantage of the fact that most dimensions are nearly constant over time. We can preserve the independent dimensional structure with only relatively minor adjustments to contend with the changes. We refer to these nearly constant dimensions as slowly changing dimensions. Since Ralph Kimball first introduced the notion of slowly changing dimensions in 1994, some IT professionals in a never-ending quest to speak in acronymese-have termed them SCDs.
For each attribute in our dimension tables, we must specify a strategy to handle change. In other words, when an attribute value changes in the operational world, how will we respond to the change in our dimensional models? In the following section we'll describe three basic techniques for dealing with attribute changes, along with a couple hybrid approaches. You may decide that you need to employ a combination of these techniques within a single dimension table.

Type 1: Overwrite the Value
With the type 1 response, we merely overwrite the old attribute value in the dimension row, replacing it with the current value. In so doing, the attribute always reflects the most recent assignment."""

# Ground Truth dla: LICENCJAT END-7.pdf
# Kategoria: Simple Text (Polish)
# Wyzwania: Polskie znaki, przypisy dolne (footers) wcinające się w tekst, dzielenie wyrazów (hyphenation).
# Uwaga: Usunąłem przypisy bibliograficzne z dołu strony, aby sprawdzić, czy biblioteka potrafi oddzielić treść od stopki.

ground_truth_simple_3= """1. ROZDZIAŁ – CZĘŚĆ TEORETYCZNA
Rozdział ten przedstawia streszczoną historię polskiej motoryzacji i potencjalne wytłumaczenie dzisiejszego stanu rynku motoryzacyjnego. Przedstawiono tutaj także aktualne badania rynku samochodów używanych w Polsce. Zawarto również istotę problemu, z jakim kupujący oraz sprzedający muszą mierzyć się przy zawieraniu transakcji.

1.1 Historia rynku motoryzacyjnego w Polsce
Na kształt współczesnego rynku samochodów używanych w Polsce miało wpływ wiele czynników historycznych oraz gospodarczych. Jednym z kluczowych było znacznie późniejsze wejście Polski w erę motoryzacji w stosunku do reszty świata.
W okresie Polskiej Rzeczypospolitej Ludowej produkcja samochodów osobowych w Polsce była ograniczona i średnio rozwinięta, co wynikało z niskiego rozwoju technologicznego oraz centralnie planowanej gospodarki. Produkcja już wtedy była znacznie niższa niż w krajach zachodu. Dla przykładu, w roku 1985 Polska wyprodukowała 283 tys. samochodów osobowych, a w tym samym czasie produkcja we Włoszech wyniosła 1,2 mln, we Francji 2,6 mln, a w USA-8 mln. Głównymi ośrodkami produkcji w tamtych czasach były rodzime zakłady motoryzacyjne, takie jak Fabryka Samochodów Osobowych (FSO) w Warszawie (produkująca m.in.: Poloneza, Fiata 125p, Syrenkę) oraz Fabryka Samochodów Małolitrażowych (FSM) w Bielsku- Białej i Tychach (produkcja kultowego Polskiego Fiata 126p). To właśnie te fabryki odgrywały kluczową rolę w zaspokajaniu popytu na samochodu osobowe. Świadczy o tym liczba zarejestrowanych w kraju samochodów osobowych w 1989 roku, która wyniosła 4,85 mln, z czego aż około 4 mln stanowiły pojazdy produkcji krajowej - w tym około 2,2 miliona Polskich Fiatów 126p oraz ponad milion Fiatów 125.
Punktem zwrotnym na polskim rynku była zmiana ustroju państwa w 1989 roku. W jej wyniku zakłady produkcji samochodów zostały sprywatyzowane, co otworzyło rynek na kapitał zagraniczny. Decyzje te, postrzegane wówczas jako korzystne z punktu widzenia rozwoju rynku i jego integracji z gospodarką europejską, okazały się katastrofalne dla rodzimych producentów. Polskie fabryki zostały przejęte przez

R. Klimkowska, Przemysł samochodów osobowych w Polsce i jego uwarunkowania w latach transformacji systemowej 1990-2014, „Nierówności Społeczne a Wzrost Gospodarczy" 2015, Nr 43, s. 241-242.
M. Menes, Rozwój motoryzacji indywidualnej w Polsce w latach 1990-2015,,,Przegląd Komunikacyjny" 2018, R.73, Nr 4, s. 16"""

ground_truth_simple_4 = """Uniqueness of the Principal Components
While in theory the principal components need not be unique, in almost all practical settings they are (up to sign flips). This means that two different software packages will yield the same principal component loading vectors, although the signs of those loading vectors may differ. The signs may differ because each principal component loading vector specifies a direction in p-dimensional space: flipping the sign has no effect as the direction does not change. (Consider Figure 6.14 the principal component loading vector is a line that extends in either direction, and flipping its sign would have no effect.) Similarly, the score vectors are unique up to a sign flip, since the variance of Z is the same as the variance of -Z. It is worth noting that when we use (12.5) to approximate $x_{ij}$ we multiply $z_{im}$ by $\phi_{jm}$. Hence, if the sign is flipped on both the loading and score vectors, the final product of the two quantities is unchanged.

Deciding How Many Principal Components to Use
In general, an $n \times p$ data matrix X has min(n-1,p) distinct principal components. However, we usually are not interested in all of them; rather, we would like to use just the first few principal components in order to visualize or interpret the data. In fact, we would like to use the smallest number of principal components required to get a good understanding of the data. How many principal components are needed? Unfortunately, there is no single (or simple!) answer to this question.
We typically decide on the number of principal components required to visualize the data by examining a scree plot, such as the one shown in the left-hand panel of Figure 12.3. We choose the smallest number of principal components that are required in order to explain a sizable amount of the variation in the data. This is done by eyeballing the scree plot, and looking for a point at which the proportion of variance explained by each subsequent principal component drops off. This drop is often referred to as an elbow in the scree plot. For instance, by inspection of Figure 12.3, one might conclude that a fair amount of variance is explained by the first two principal components, and that there is an elbow after the second component. After all, the third principal component explains less than ten percent of the variance in the data, and the fourth principal component explains less than half that and so is essentially worthless.
However, this type of visual analysis is inherently ad hoc. Unfortunately, there is no well-accepted objective way to decide how many principal components are enough. In fact, the question of how many principal components are enough is inherently ill-defined, and will depend on the specific area of application and the specific data set. In practice, we tend to look at the first few principal components in order to find interesting patterns in the data. If no interesting patterns are found in the first few principal components, then further principal components are unlikely to be of interest. Conversely, if the first few principal components are interesting, then we typically continue to look at subsequent principal components until no further interesting patterns are found. This is admittedly a subjective ap-"""
# Out:
# <>:43: SyntaxWarning: invalid escape sequence '\p'
# <>:43: SyntaxWarning: invalid escape sequence '\p'
# /var/folders/vd/vvz78nnx07g_wkmp4mgsfpt80000gn/T/ipykernel_25872/2893197602.py:43: SyntaxWarning: invalid escape sequence '\p'
#   ground_truth_simple_4 = """Uniqueness of the Principal Components

# %% [markdown]
# Biblioteki, których działanie sprawdzę i porównam to:
# PyMuPDF (fitz) – Faworyt w kategorii Zwykły Tekst (szybkość).
#
# pdfplumber – Faworyt w kategorii Tabela (precyzja pozycjonowania).
#
# Marker (lub Docling) – "Czarny koń" oparty na AI, który próbuje robić wszystko naraz (świetny test, czy AI wygrywa z klasycznym kodem).

# %%
from IPython.display import HTML

HTML('''<script>
code_show=true; 
function code_toggle() {
 if (code_show){
 $('div.input').hide();
 } else {
 $('div.input').show();
 }
 code_show = !code_show
} 
$( document ).ready(code_toggle);
</script>
<form action="javascript:code_toggle()"><input type="submit" value="Kliknij tutaj, aby przełączyć widoczność kodu"></form>''')
# Out:
# <script>
# code_show=true;
# function code_toggle() {
#  if (code_show){
#  $('div.input').hide();
#  } else {
#  $('div.input').show();
#  }
#  code_show = !code_show
# }
# $( document ).ready(code_toggle);
# </script>
# <form action="javascript:code_toggle()"><input type="submit" value="Kliknij tutaj, aby przełączyć widoczność kodu"></form>

# %% [markdown]
# # Proste PDF

# %% [markdown]
# ## PyMuPDF

# %%
from rapidfuzz import fuzz
import time
import fitz  # PyMuPDF
import pdfplumber
import time
from rapidfuzz import fuzz
import docling
from docling.document_converter import DocumentConverter

# %% [markdown]
# Wpierw zobaczmy jak trzy biblioteki poradzą sobie na ekstrakcji danych ze strony z angielskiej ksiązki. Ponizej przedstawiam jak wyglada strona (pdf):

# %%
from pdf2image import convert_from_path
from IPython.display import display

# Ścieżka do pliku
pdf_path = "data/texts/Ralph_Kimball_Margy_Ross-The_Data_Warehouse_Toolkit-EN-121.pdf"

# Konwertuj tylko pierwszą stronę (first_page=1, last_page=1)
# Jeśli masz problem z Popplerem, pamiętaj o parametrze poppler_path!
images = convert_from_path(pdf_path, first_page=1, last_page=1)

# Wyświetl
display(images[0])
# Out:
# <PIL.PpmImagePlugin.PpmImageFile image mode=RGB size=1500x1850>

# %%
def benchmark_libraries(pdf_path, ground_truth):
    results = []
    print("Testowanie PyMuPDF...")
    start = time.perf_counter()
    try:
        doc = fitz.open(pdf_path)
        text_pymu = ""
        for page in doc:
            text_pymu += page.get_text() + "\n"
        t_pymu = time.perf_counter() - start
        score_pymu = fuzz.ratio(text_pymu.strip(), ground_truth.strip())
        results.append({"Lib": "PyMuPDF", "Time": t_pymu, "Score": score_pymu, "Text": text_pymu})
    except Exception as e:
        print(f"PyMuPDF Error: {e}")

    print("Testowanie pdfplumber...")
    start = time.perf_counter()
    try:
        text_plumb = ""
        with pdfplumber.open(pdf_path) as pdf:
            for page in pdf.pages:
                text_plumb += (page.extract_text() or "") + "\n"
        t_plumb = time.perf_counter() - start
        score_plumb = fuzz.ratio(text_plumb.strip(), ground_truth.strip())
        results.append({"Lib": "pdfplumber", "Time": t_plumb, "Score": score_plumb, "Text": text_plumb})
    except Exception as e:
        print(f"pdfplumber Error: {e}")

    print("Testowanie Docling (AI)...")
    start = time.perf_counter()
    try:
        converter = DocumentConverter()
        result = converter.convert(pdf_path)
        text = result.document.export_to_markdown()
        
        duration = time.perf_counter() - start
        score = fuzz.ratio(text.strip(), ground_truth.strip())
        results.append({"Lib": "Docling (AI)", "Time": duration, "Score": score, "Text": text})
    except Exception as e:
        print(f"   Błąd: {e}")

    print("PdfPlumber"+"="*40)
    print(text_plumb)
    print("PyMuPDF"+"="*40)
    print(text_pymu)
    print("Docling"+"="*40)
    print(text)

    print("\n" + "="*40)
    print(f"{'BIBLIOTEKA':<15} | {'CZAS (s)':<10} | {'DOKŁADNOŚĆ':<10}")
    print("-" * 40)
    for res in results:
        print(f"{res['Lib']:<15} | {res['Time']:.4f}     | {res['Score']:.2f}%")
    print("="*40)
    
    return results

wyniki = benchmark_libraries("data/texts/oldmansea-20.pdf", ground_truth_simple_1)
# Out:
# Testowanie PyMuPDF...
# Testowanie pdfplumber...
# Testowanie Docling (AI)...
# PdfPlumber========================================
# The Old Man and the Sea Asiaing.com
# [51] But you haven’t got the boy, he thought. You have only yourself and you had
# better work back to the last line now, in the dark or not in the dark, and cut it away and
# hook up the two reserve coils.
# So he did it. It was difficult in the dark and once the fish made a surge that pulled
# him down on his face and made a cut below his eye. The blood ran down his cheek a little
# way. But it coagulated and dried before it reached his chin and he worked his way back to
# the bow and rested against the wood. He adjusted the sack and carefully worked the line
# so that it came across a new part of his shoulders and, holding it anchored with his
# shoulders, he carefully felt the pull of the fish and then felt with his hand the progress of
# the skiff through the water.
# ...

# %% [markdown]
# # Tabele/Faktury

# %% [markdown]
# Ten kod nie sprawdza podobieństwa tekstu. On sprawdza, czy biblioteka "zaliczyła" zadania.
#
# Zasady punktacji (0-4 pkt):
#
# Czy znalazła Numer Faktury (INV-3337)?
#
# Czy znalazła Odbiorcę (Test Business)?
#
# Czy znalazła Kwotę w tabeli (85.00 obok Web Design)?
#
# Decydujące: Czy wykryła TABELĘ (zwróciła listę/strukturę lub Markdown |...|)?

# %% [markdown]
# biblioteki ❌ pypdf: Odpada. Wyciągnie tekst "ciurkiem". Nie rozróżnisz, co jest tabelą, a co tekstem. Nie ma pojęcia o wierszach i kolumnach.
#
# ❌ PyMuPDF (zwykły fitz): Odpada. To samo co wyżej. Szybki, ale "płaski".
#
# ❌ Camelot: Odpada jako samodzielne narzędzie. Wyciągnie tabelę idealnie, ale zignoruje numer faktury i nadawcę (bo są poza tabelą).
#
# ❌ Tesseract: Odpada. Bez skomplikowanego post-processingu (analizy współrzędnych boxów) zwróci tylko ścianę tekstu. ODPADAJĄ

# %%
import pandas as pd
import pdfplumber
from docling.document_converter import DocumentConverter
import re

# Ścieżka do folderu
PDF_PATH = "data/invoices"

# 1. GROUND TRUTH (Wzorcowe dane)
GT_INVOICE_NUM = "INV-3337"
GT_RECIPIENT = "Test Business"

# 2. FUNKCJE POMOCNICZE
def clean_text(text):
    if not isinstance(text, str): return str(text)
    text = text.replace("\n", " ").replace("\r", "")
    return re.sub(' +', ' ', text).strip()

# Globalny słownik na wyniki
final_report = {}

def evaluate_extraction(lib_name, invoice_num, recipient, extracted_df):
    """Ocenia jakość ekstrakcji w sposób ścisły (Strict Mode)."""
    print(f"\n--- 🕵️‍♂️ OCENA DLA: {lib_name} ---")
    
    # --- 1. Pola tekstowe ---
    inv_status = "✅ OK" if invoice_num and GT_INVOICE_NUM in invoice_num else f"❌ BŁĄD (Oczek: {GT_INVOICE_NUM})"
    rec_status = "✅ OK" if recipient and GT_RECIPIENT in recipient else f"❌ BŁĄD (Oczek: {GT_RECIPIENT})"
    
    print(f"Numer faktury: {invoice_num} -> {inv_status}")
    print(f"Odbiorca:      {recipient} -> {rec_status}")
    
    # --- 2. Tabela (Analiza Strukturalna) ---
    table_status = "❌ Tabela nie znaleziona"
    details = []
    
    if extracted_df is not None and not extracted_df.empty:
        # Normalizacja
        extracted_df = extracted_df.map(clean_text)
        extracted_df.columns = [clean_text(col) for col in extracted_df.columns]
        
        rows_count = len(extracted_df)
        cols_count = len(extracted_df.columns)
        
        # DEFINICJA WARTOŚCI KLUCZOWYCH (MUSZĄ BYĆ W JEDNYM WIERSZU)
        key_price = "$85.00"
        key_qty = "1.00"
        key_desc_part = "Web Design"
        
        # Krok A: Szukamy "Idealnego Wiersza"
        found_perfect_row = False
        found_fragmented_data = False
        
        for idx, row in extracted_df.iterrows():
            row_str = " ".join(row.values.astype(str))
            
            has_price = key_price in row_str
            has_qty = key_qty in row_str
            has_desc = key_desc_part in row_str
            
            if has_price and has_qty and has_desc:
                found_perfect_row = True
                break # Mamy to!
            
            if has_price or has_desc:
                found_fragmented_data = True

        # Krok B: Ocena "Śmieci" (Garbage Rows)
        # Oczekujemy 1 wiersza danych. Jeśli jest ich > 3 (np. nagłówki + dane + śmieci), to błąd struktury.
        is_clean_structure = rows_count <= 3 
        
        # Krok C: Finalny Werdykt
        if found_perfect_row:
            if is_clean_structure:
                table_status = "✅ Tabela wczytana bezbłędnie"
            else:
                table_status = "⚠️ Tabela zawiera dane, ale dużo śmieci"
                details.append(f"Wykryto aż {rows_count} wierszy (oczekiwano ok. 1)")
        elif found_fragmented_data:
            table_status = "⚠️ Dane rozrzucone / Błędy formatowania"
            details.append("Dane są, ale nie w jednym wierszu (np. pocięty opis lub przesunięte kolumny)")
        else:
            table_status = "❌ Tabela zawiera błędne dane"
            details.append("Nie znaleziono kluczowych wartości ($85.00, 1.00)")

    else:
        details.append("DataFrame jest pusty lub None")

    # Wypisanie wyniku
    details_str = f"({', '.join(details)})" if details else ""
    print(f"Status tabeli: {table_status} {details_str}")
    if extracted_df is not None:
        print(f"Wymiary tabeli: {extracted_df.shape} (Wiersze x Kolumny)")

    # Zapisz do raportu
    final_report[lib_name] = {
        "Invoice #": inv_status,
        "Recipient": rec_status,
        "Table Status": table_status,
        "Details": details_str
    }

print("✅ Setup Strict Mode zakończony.")
# Out:
# ✅ Setup Strict Mode zakończony.

# %% [markdown]
# pdfplumber

# %%
# --- KAFELEK 2: pdfplumber ---
print(">>> Testowanie: pdfplumber")

extracted_inv = None
extracted_rec = None
extracted_df = None

with pdfplumber.open(PDF_PATH) as pdf:
    page = pdf.pages[0]
    text = page.extract_text()
    
    # 1. Ekstrakcja danych tekstowych (prosta heurystyka)
    # Szukamy "Invoice Number" i bierzemy to co jest linię niżej/obok
    if "Invoice Number" in text:
        # pdfplumber zwraca tekst z layoutem, czasem trzeba szukać po słowach kluczowych
        extracted_inv = "INV-3337" if "INV-3337" in text else None # Uproszczenie dla demo
    
    if "To:" in text:
        # Szukanie bloku pod "To:"
        lines = text.split('\n')
        for i, line in enumerate(lines):
            if "To:" in line and i + 1 < len(lines):
                extracted_rec = lines[i+1] # Zakładamy że odbiorca jest linię niżej
                break

    # 2. Ekstrakcja Tabeli
    # pdfplumber zwraca listę list
    tables = page.extract_tables()
    for table in tables:
        if table and "Service" in str(table[0]):
            extracted_df = pd.DataFrame(table[1:], columns=table[0])
            break

# --- WYNIKI ---
print(f"Znaleziony Numer: {extracted_inv}")
print(f"Znaleziony Odbiorca: {extracted_rec}")
print("\n--- PODGLĄD TABELI (pdfplumber) ---")
if extracted_df is not None:
    display(extracted_df) # Jeśli używasz Jupyter, display() jest lepsze niż print()
else:
    print("Brak tabeli")

# Ocena
evaluate_extraction("pdfplumber", extracted_inv, extracted_rec, extracted_df)
# Out:
# >>> Testowanie: pdfplumber
# Znaleziony Numer: INV-3337
# Znaleziony Odbiorca: Test Business
#
# --- PODGLĄD TABELI (pdfplumber) ---
# Brak tabeli
#
# --- 🕵️‍♂️ OCENA DLA: pdfplumber ---
# Numer faktury: INV-3337 -> ✅ OK
# Odbiorca:      Test Business -> ✅ OK
# Status tabeli: ❌ Tabela nie znaleziona (DataFrame jest pusty lub None)

# %% [markdown]
# Kafelek 3: Camelot

# %%
# --- KAFELEK 3: Camelot ---
print(">>> Testowanie: Camelot")

extracted_inv = "N/A (Camelot nie czyta tekstu)"
extracted_rec = "N/A (Camelot nie czyta tekstu)"
extracted_df = None

try:
    # flavor='stream' jest kluczowy dla faktur bez linii kratek
    tables = camelot.read_pdf(PDF_PATH, pages='1', flavor='stream')
    
    for t in tables:
        df = t.df
        # Camelot w trybie stream często nie ma nagłówków w wierszu 0
        # Szukamy tabeli, która ma słowo "Service" w treści
        full_text = df.to_string()
        if "Service" in full_text:
            # Próba ustawienia nagłówków
            # Zakładamy, że pierwszy wiersz to nagłówki
            df.columns = df.iloc[0]
            extracted_df = df[1:].reset_index(drop=True)
            break
            
except Exception as e:
    print(f"Błąd Camelota: {e}")

# --- WYNIKI ---
print(f"Znaleziony Numer: {extracted_inv}")
print(f"Znaleziony Odbiorca: {extracted_rec}")
print("\n--- PODGLĄD TABELI (Camelot) ---")
if extracted_df is not None:
    display(extracted_df)
else:
    print("Brak tabeli")

# Ocena
evaluate_extraction("Camelot", None, None, extracted_df)
# Out:
# >>> Testowanie: Camelot
# Znaleziony Numer: N/A (Camelot nie czyta tekstu)
# Znaleziony Odbiorca: N/A (Camelot nie czyta tekstu)
#
# --- PODGLĄD TABELI (Camelot) ---
# Brak tabeli
#
# --- 🕵️‍♂️ OCENA DLA: Camelot ---
# Numer faktury: None -> ❌ BŁĄD (Oczek: INV-3337)
# Odbiorca:      None -> ❌ BŁĄD (Oczek: Test Business)
# Status tabeli: ❌ Tabela nie znaleziona (DataFrame jest pusty lub None)

# %% [markdown]
# Kafelek 4: Docling (AI)

# %%
# --- KAFELEK 4: Docling ---
print(">>> Testowanie: Docling")

extracted_inv = None
extracted_rec = None
extracted_df = None

try:
    converter = DocumentConverter()
    res = converter.convert(PDF_PATH)
    
    # 1. Tekst (Markdown)
    md_text = res.document.export_to_markdown()
    
    # Docling jest mądry, szukamy w markdownie
    if "INV-3337" in md_text: extracted_inv = "INV-3337"
    if "Test Business" in md_text: extracted_rec = "Test Business"
    
    # 2. Tabela (Obiektowo)
    for table in res.document.tables:
        df = table.export_to_dataframe()
        if "Service" in df.columns or "Service" in df.to_string():
            extracted_df = df
            break

except Exception as e:
    print(f"Błąd Docling: {e}")

# --- WYNIKI ---
print(f"Znaleziony Numer: {extracted_inv}")
print(f"Znaleziony Odbiorca: {extracted_rec}")
print("\n--- PODGLĄD TABELI (Docling) ---")
if extracted_df is not None:
    display(extracted_df)
else:
    print("Brak tabeli")

# Ocena
evaluate_extraction("Docling", extracted_inv, extracted_rec, extracted_df)
# Out:
# >>> Testowanie: Docling
# Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# Znaleziony Numer: INV-3337
# Znaleziony Odbiorca: Test Business
#
# --- PODGLĄD TABELI (Docling) ---
#   Hrs/Qty                                     Service Rate/Price Adjust  \
# 0    1.00  Web Design This is a sample description...     $85.00  0.00%
#
#   Sub Total
# 0    $85.00
# --- 🕵️‍♂️ OCENA DLA: Docling ---
# Numer faktury: INV-3337 -> ✅ OK
# Odbiorca:      Test Business -> ✅ OK
# Status tabeli: ✅ Tabela wczytana bezbłędnie
# Wymiary tabeli: (1, 5) (Wiersze x Kolumny)

# %% [markdown]
# PyMuPDF4LLM

# %%
from io import StringIO
print(">>> Testowanie: PyMuPDF4LLM")

extracted_inv = None
extracted_rec = None
extracted_df = None

try:
    md_text = pymupdf4llm.to_markdown(PDF_PATH)
    
    # 1. Tekst
    if "INV-3337" in md_text: extracted_inv = "INV-3337"
    if "Test Business" in md_text: extracted_rec = "Test Business"
    
    lines = [line.strip() for line in md_text.split('\n') if '|' in line]
    
    valid_table_lines = []
    capture = False
    header_found = False
    
    for line in lines:
        if "Service" in line:
            capture = True
            header_found = True
        
        if capture:
            if "---" not in line: 
                valid_table_lines.append(line)
    
    if header_found and len(valid_table_lines) > 1:
        cleaned_data = []
        for row in valid_table_lines:
            cells = [c.strip() for c in row.split('|') if c.strip() != '']
            cleaned_data.append(cells)
            
        if cleaned_data:
            extracted_df = pd.DataFrame(cleaned_data[1:], columns=cleaned_data[0])

except Exception as e:
    print(f"Błąd PyMuPDF4LLM: {e}")

# --- WYNIKI ---
print(f"Znaleziony Numer: {extracted_inv}")
print(f"Znaleziony Odbiorca: {extracted_rec}")
print("\n--- PODGLĄD TABELI (PyMuPDF4LLM) ---")
if extracted_df is not None:
    display(extracted_df)
else:
    print("Brak tabeli (lub błąd parsowania MD)")

# Ocena
evaluate_extraction("PyMuPDF4LLM", extracted_inv, extracted_rec, extracted_df)
# Out:
# >>> Testowanie: PyMuPDF4LLM
# Znaleziony Numer: INV-3337
# Znaleziony Odbiorca: Test Business
#
# --- PODGLĄD TABELI (PyMuPDF4LLM) ---
#                                        Hrs/Qty  \
# 0                                         1.00
# 1                                    Sub Total
# 2                                      Tax<br>
# 3                                **Total**<br>
# 4  [Thanks for choosing DEMO - Sliced Invoices
#
#                                              Service d<br>Rate/Price  \
# 0  Web Design<br>This is a sample description...<br>      $85.00<br>
# 1                                             $85.00             NaN
# 2                                              $8.50             NaN
# 3                                         **$93.50**             NaN
# 4  admin@slicedinvoices.com](http://slicedinvoice...             NaN
#
#       Adjust Sub Total
# 0  0.00%<br>    $85.00
# 1        NaN       NaN
# 2        NaN       NaN
# 3        NaN       NaN
# ...
